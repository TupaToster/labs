# %%
import numpy as np
import matplotlib.pyplot as plt
# signal is sin
# part 1
R = 1 * 10**3
C = 1 * 10**-6
tau = 10**-3
f_0 = 1600

U_0 = 145
U_f0_exp = 0.7*145

f0_exp = 850

f = [2**i * f0_exp for i in range(-2, 4)]
f = np.array(f)
K = np.array([155, 158, 99.9, 53.1, 29.4, 18.7]) / U_0

plt.figure(figsize=(16, 9), dpi=200)

plt.grid()

plt.plot(np.log2(f / f0_exp), 20 * np.log10(K))

plt.show()

# %%
# После подключения прямоугольного сигнала получаем
# tau = 1/(2 * np.pi * 850)
tau = 0.0001872

# %%
#часть такая то (4) собирается дифф схема
# f_0 - та же
K_d = 20 * np.log10 (np.array ([655, 735, 732, 708, 694, 660]))
K_d
# Out:
# array([56.324826  , 57.32574678, 57.29022162, 57.00066515, 56.82718941,
#        56.39087871])
